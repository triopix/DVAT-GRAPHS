# %% [markdown]
# Pos/Time Graph - Data Visualized - __Trial 1__

# %% [markdown]
# Importing the __pandas__ library to read our csv data from google sheets

# %%
import pandas as pd

# %% [markdown]
# Importing our graphing libraries

# %%
import matplotlib.pyplot as plt
import scienceplots as sp

# %%
plt.style.use(['science', 'grid', 'notebook', 'no-latex'])

# %%
trial_one = pd.read_csv('trials/trial_one.csv')

# %%
trial_one
# Out:
#     Time  Pos/Disp.
# 0   0.00          0
# 1   0.98          3
# 2   1.47          6
# 3   1.92          9
# 4   2.21         12
# 5   2.58         15
# 6   3.50         18
# 7   4.00         21
# 8   4.31         24
# 9   4.86         27
# 10  4.90         30
# 11  5.60         33
# 12  5.80         36
# 13  6.31         39
# 14  6.90         42
# 15  7.30         45
# 16  7.60         48
# 17  8.26         51
# 18  8.30         54
# 19  8.93         57
# 20  9.44         60
# 21  9.55         63

# %%
trial_one_plot = trial_one[['Time', 'Pos/Disp.']]

# %%
trial_one_plot.plot(x='Time', y='Pos/Disp.', title='Position vs. Time', xlabel='Time (s)', ylabel='Position (m)', linestyle='-', color='red')
plt.show()
